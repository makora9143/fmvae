# %%
import pandas as pd
import numpy as np
from scipy.sparse import lil_matrix, csr_matrix

# %%
artists = pd.read_csv('./data/last.fm/artists.dat', '\t')
tags = pd.read_csv('./data/last.fm/tag.dat', '\t')
user_artists = pd.read_csv('./data/last.fm/user_artists.dat', '\t')
user_taggedartists = pd.read_csv('./data/last.fm/user_taggedartists.dat', '\t')
# user_friends = pd.read_csv('./data/last.fm/user_friends.dat', '\t')
users = pd.read_csv('./data/last.fm/user.dat', '\t')
# tag_artists = pd.read_csv('./data/last.fm/tag_artists.dat', '\t')

# %%
artists.columns = ['artistID', 'name', 'url', 'pictureURL']

# %%
artists
# Out:
#        artistID                               name  \
# 0             1                       MALICE MIZER
# 1             2                    Diary of Dreams
# 2             3                  Carpathian Forest
# 3             4                       Moi dix Mois
# 4             5                        Bella Morte
# 5             6                          Moonspell
# 6             7                     Marilyn Manson
# 7             8                        DIR EN GREY
# 8             9                        Combichrist
# 9            10                            Grendel
# 10           11                           Agonoize
# 11           12                           Behemoth
# 12           13                             Hocico
# 13           15                       Dimmu Borgir
# 14           16              London After Midnight
# 15           17                       Psyclon Nine
# 16           18                    The Crüxshadows
# ...

# %%
tags
# Out:
#        tagID                   tagValue
# 0          1                      metal
# 1          2          alternative metal
# 2          3                  goth rock
# 3          4                black metal
# 4          5                death metal
# 5          6           industrial metal
# 6          7               gothic metal
# 7          8                 terror ebm
# 8          9         electro-industrial
# 9         10                  harsh ebm
# 10        11           post black metal
# 11        12                  aggrotech
# 12        13                   chillout
# 13        14                    ambient
# 14        15                  downtempo
# 15        16                   new wave
# 16        17                  synth pop
# 17        18                 electronic
# 18        19                       80's
# 19        20                     lounge
# 20        21                   trip-hop
# 21        22                  acid jazz
# ...

# %%
tmp = pd.merge(user_taggedartists, artists, on='artistID', how='inner')

# %%
tmp.groupby(['tagID', 'artistID']).size().to_csv('./data/last.fm/tag_artists.dat', sep='\t')
