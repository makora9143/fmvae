# %%
import pandas as pd
import numpy as np
from scipy.sparse import lil_matrix, csr_matrix

# %%
artists = pd.read_csv('./data/last.fm/artists.dat', '\t')
tags = pd.read_csv('./data/last.fm/tags.dat', '\t')
user_artists = pd.read_csv('./data/last.fm/user_artists.dat', '\t')
user_taggedartists = pd.read_csv('./data/last.fm/user_taggedartists.dat', '\t')
user_friends = pd.read_csv('./data/last.fm/user_friends.dat', '\t')

# %%
user_ids = user_friends.userID.drop_duplicates().reset_index(drop=True)

# %%
len(user_artists[(user_artists.userID == user_ids.iloc[0]) & (user_artists.artistID==51)])
# Out:
# 1

# %%
X_shape = (len(user_ids), len(artists))

# %%
len(user_artists)
# Out:
# 92834

# %%
index = 7902

# %%
uid, aid, w = user_artists.iloc[index]

# %%
user_artists.iloc[index]
# Out:
# userID       168
# artistID    3691
# weight       439
# Name: 7902, dtype: int64

# %%
user_friends[(user_friends.userID == uid)].friends
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a4fd1e83aeec> in <module>()
# ----> 1 user_friends[(user_friends.userID == uid)].friends
#
# NameError: name 'uid' is not defined

# %%
W = np.random.rand(1892, 20)
H = np.random.rand(17632, 20)
A = np.random.rand(11946, 20)
B = np.random.rand(1892, 20)

# %%
for i in range(W.shape[0]):
    for k in range(20):
        J_i = X.nonzero()[1]
        total = 0
        for j in J_i:
            total += X[i, j] / np.dot(W[i,:], H.T[:, j]) * H[j, k]
        M_i = Y.nonzero()[0]
        for m in M_i:
            total += beta * Z[i, m] / np.dot(W[i, :], B.T[m, :]) * B[m, k]
        W[i, k] = W[i, k] * () / ()
    
for k in range(20):
    for j in range(H.T.shape[1]):
        H.T[k, j] = H.T[k, j] * () / ()

for n in range(A.shape[0]):
    for k in range(20):
        A[n, k] = A[n, k] * () / ()

for k in range(20):
    for m in range(B.T.shape[1]):
        B.T[k, m] = B.T[k, m] * () / ()

# %%
test = lil_matrix((100, 100))

# %%
test[3, 50] = 20
test[3, 23] = 3
test[3, 93] = 34

# %%
H[test[3].tocsr().nonzero()[1], :].shape
# Out:
# (3, 20)

# %%
artists
# Out:
#           id                               name  \
# 0          1                       MALICE MIZER
# 1          2                    Diary of Dreams
# 2          3                  Carpathian Forest
# 3          4                       Moi dix Mois
# 4          5                        Bella Morte
# 5          6                          Moonspell
# 6          7                     Marilyn Manson
# 7          8                        DIR EN GREY
# 8          9                        Combichrist
# 9         10                            Grendel
# 10        11                           Agonoize
# 11        12                           Behemoth
# 12        13                             Hocico
# 13        15                       Dimmu Borgir
# 14        16              London After Midnight
# 15        17                       Psyclon Nine
# 16        18                    The Crüxshadows
# 17        19                         :wumpscut:
# ...

# %%
user_ids
# Out:
# 0          2
# 1          3
# 2          4
# 3          5
# 4          6
# 5          7
# 6          8
# 7          9
# 8         10
# 9         11
# 10        12
# 11        13
# 12        14
# 13        15
# 14        16
# 15        17
# 16        18
# 17        20
# 18        21
# 19        22
# 20        23
# 21        24
# 22        25
# 23        26
# 24        27
# 25        28
# 26        29
# 27        30
# 28        31
# 29        32
#         ...
# 1862    2066
# 1863    2067
# 1864    2068
# 1865    2069
# 1866    2070
# 1867    2071
# 1868    2072
# 1869    2075
# 1870    2076
# 1871    2077
# 1872    2078
# 1873    2079
# 1874    2080
# 1875    2081
# 1876    2083
# 1877    2084
# 1878    2085
# 1879    2086
# 1880    2087
# 1881    2088
# 1882    2090
# 1883    2091
# 1884    2092
# 1885    2093
# 1886    2094
# 1887    2095
# 1888    2096
# 1889    2097
# 1890    2099
# 1891    2100
# Name: userID, Length: 1892, dtype: int64

# %%
tags
# Out:
#        tagID                   tagValue
# 0          1                      metal
# 1          2          alternative metal
# 2          3                  goth rock
# 3          4                black metal
# 4          5                death metal
# 5          6           industrial metal
# 6          7               gothic metal
# 7          8                 terror ebm
# 8          9         electro-industrial
# 9         10                  harsh ebm
# 10        11           post black metal
# 11        12                  aggrotech
# 12        13                   chillout
# 13        14                    ambient
# 14        15                  downtempo
# 15        16                   new wave
# 16        17                  synth pop
# 17        18                 electronic
# 18        19                       80's
# 19        20                     lounge
# 20        21                   trip-hop
# 21        22                  acid jazz
# ...

# %%
user_artists
# Out:
#        userID  artistID  weight
# 0           2        51   13883
# 1           2        52   11690
# 2           2        53   11351
# 3           2        54   10300
# 4           2        55    8983
# 5           2        56    6152
# 6           2        57    5955
# 7           2        58    4616
# 8           2        59    4337
# 9           2        60    4147
# 10          2        61    3923
# 11          2        62    3782
# 12          2        63    3735
# 13          2        64    3644
# 14          2        65    3579
# 15          2        66    3312
# 16          2        67    3301
# 17          2        68    2927
# 18          2        69    2720
# 19          2        70    2686
# 20          2        71    2654
# 21          2        72    2619
# 22          2        73    2584
# 23          2        74    2547
# 24          2        75    2397
# 25          2        76    2382
# 26          2        77    2120
# 27          2        78    2119
# ...

# %%
user_friends
# Out:
#        userID  friendID
# 0           2       275
# 1           2       428
# 2           2       515
# 3           2       761
# 4           2       831
# 5           2       909
# 6           2      1209
# 7           2      1210
# 8           2      1230
# 9           2      1327
# 10          2      1585
# 11          2      1625
# 12          2      1869
# 13          3        78
# 14          3       255
# 15          3       460
# 16          3       837
# 17          3      1740
# 18          3      1801
# 19          3      1975
# 20          4        99
# 21          4       124
# 22          4       211
# 23          4       264
# 24          4       493
# 25          4       520
# 26          4       534
# 27          4       850
# 28          4      1103
# 29          4      2080
# ...       ...       ...
# 25404    2091      1458
# 25405    2091      1537
# 25406    2091      1581
# 25407    2091      1793
# 25408    2091      1804
# 25409    2091      1948
# ...

# %%
25434 / 1892 ** 2
# Out:
# 0.007105136124507775

# %%
user_taggedartists.groupby(['tagID', 'artistID']).count()
# Out:
#                 userID  day  month  year
# tagID artistID
# 1     4              2    2      2     2
#       7             25   25     25    25
#       8              4    4      4     4
#       15             1    1      1     1
#       20             1    1      1     1
#       25             7    7      7     7
#       28             2    2      2     2
#       30             1    1      1     1
#       45             1    1      1     1
#       47             1    1      1     1
#       65             1    1      1     1
#       67             1    1      1     1
#       72             1    1      1     1
#       152            1    1      1     1
#       176            2    2      2     2
#       181            4    4      4     4
#       188            9    9      9     9
#       198           34   34     34    34
#       217            1    1      1     1
#       226            2    2      2     2
#       230            1    1      1     1
# ...

# %%
109750 / (11946 * 17632)
# Out:
# 0.0005210512490721253

# %%
X = lil_matrix((1892, 17632))

# %%
X[0, 4] = 10

# %%
X[0].tocsr().nonzero()[0]
# Out:
# array([0], dtype=int32)
